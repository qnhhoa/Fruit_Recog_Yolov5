# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15978, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 15978 (delta 89), reused 118 (delta 76), pack-reused 15831
# Receiving objects: 100% (15978/15978), 14.61 MiB | 3.39 MiB/s, done.
# Resolving deltas: 100% (10958/10958), done.
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !cd /home/thuannd/Yolov5/yolov5
# !pip install -r requirements.txt  # install
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/GuavaFresh3/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/PapayaRotten3/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/PomegranateFresh3/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/StrawberryFresh2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/TomatoFresh2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/DragonFruitRotten2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/MangoFresh2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/DragonFruitFresh2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/PapayaFresh2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/StrawberryUnripe2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/TomatoUnripe2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/PomegranateRotten2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/MangoUnripe2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/BananaUnripe2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/AppleFresh2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/AppleRotten2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/OrangesRotten2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/TomatoRotten2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/PapayaUnripe2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/OrangesUnripe2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/OrangesFresh2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/GuavaRotten2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/BananaRotten2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Yolov7/Dataset/Dataset2/MangoRotten2/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Fruit_Dataset/Dataset/StrawberryRotten/*.jpg /home/thuannd/Yolov5/yolov5/train/images
# !cp /home/thuannd/Fruit_Dataset/Dataset/BananaFresh/*.jpg /home/thuannd/Yolov5/yolov5/train/images

# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/GuavaFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/PapayaRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/PomegranateFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/StrawberryFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/TomatoFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/DragonFruitRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/MangoFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/DragonFruitFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/PapayaFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/StrawberryUnripe2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/TomatoUnripe2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/PomegranateRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/MangoUnripe2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/BananaUnripe2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/AppleFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/AppleRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/OrangesRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/TomatoRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/PapayaUnripe2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/OrangesUnripe2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/OrangesFresh2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/GuavaRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/BananaRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Yolov7/Dataset/Label_Dataset2/MangoRotten2/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Fruit_Dataset/Label_Dataset/StrawberryRotten/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# !cp /home/thuannd/Fruit_Dataset/Label_Dataset/BananaFresh/*.txt /home/thuannd/Yolov5/yolov5/train/labels
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...

# %%
# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
path: /home/thuannd/Yolov5/yolov5/data/mydataset.yaml  # dataset root dir
train: /home/thuannd/Yolov5/yolov5/train  # train images (relative to 'path') 128 images
val: /home/thuannd/Yolov5/yolov5/train # val images (relative to 'path') 128 images
# Classes (80 COCO classes)
names:
  0: AppleFresh
  1: AppleRotten
  2: BananaRotten
  3: BananaUnripe
  4: DragonFruitFresh
  5: DragonFruitRotten
  6: GuavaFresh
  7: GuavaRotten
  8: MangoFresh
  9: MangoRotten
  10: MangoUnripe
  11: OrangesFresh
  12: OrangesRotten
  13: OrangesUnripe
  14: PapayaFresh
  15: PapayaRotten
  16: PapayaUnripe
  17: PomegranateFresh
  18: PomegranateRotten
  19: StrawberryFresh
  20: StrawberryUnripe
  21: TomatoFresh
  22: TomatoRotten
  23: TomatoUnripe
  24: BananaFresh
  25: StrawberryRotten
# Out:
#   Cell In[4], line 2
#     path: /home/thuannd/Yolov5/yolov5/data/mydataset.yaml  # dataset root dir
#           ^
# SyntaxError: invalid syntax

# %%
#Tạo format folder train, test
# %cd /home/thuannd/Yolov5/yolov5/train

# !mkdir data
# !mkdir data/images
# !mkdir data/labels 

#!mkdir test
#!mkdir test/images
#!mkdir test/labels
# Out:
# /home/thuannd/Yolov5/yolov5/train
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !cp /home/thuannd/Yolov8/datasets/fresh_or_rotten/train/images/*.jpg /home/thuannd/Yolov5/yolov5/train/data/images
# !cp /home/thuannd/Yolov8/datasets/fresh_or_rotten/train/labels/*.txt /home/thuannd/Yolov5/yolov5/train/data/labels
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
import glob
import shutil
import cv2
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
import PIL
import torch

base_dir = os.path.join('/home/thuannd/Yolov5/yolov5/train')

train_dir = os.path.join(base_dir, 'data')
train_img_dir = os.path.join(train_dir, 'images')
train_label_dir = os.path.join(train_dir, 'labels')

def create_dir(path):
    if not os.path.exists(path):
        os.mkdir(path)

create_dir(base_dir)

create_dir(train_dir)
create_dir(train_img_dir)
create_dir(train_label_dir)

print(f'There are {len(os.listdir(train_img_dir))} train images')
print(f'There are {len(os.listdir(train_label_dir))} corresponding train labels\n')
# Out:
# There are 10012 train images
# There are 10012 corresponding train labels

# %%
# %cd /home/thuannd/Yolov5/yolov5
# !python train.py --batch 16 --img 640 --epochs 200 --data data/mydataset.yaml --weights pretrain/yolov5s.pt
# Out:
# /home/thuannd/Yolov5/yolov5
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# train: weights=pretrain/yolov5s.pt, cfg=, data=data/mydataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 7 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.9.16 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24254MiB)
# ...

# %%
# %cd /home/thuannd/Yolov5/yolov5
# !python val.py --weights runs/train/exp4/weights/best.pt --data data/mydataset.yaml --img-size=640
# Out:
# /home/thuannd/Yolov5/yolov5
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# val: data=data/mydataset.yaml, weights=['runs/train/exp4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.9.16 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24254MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7080247 parameters, 0 gradients, 16.0 GFLOPs
# val: Scanning /home/thuannd/Yolov5/yolov5/train/data/labels.cache... 10012 image
#                  Class     Images  Instances          P          R      mAP50
#                    all      10012      21947       0.93       0.96      0.976      0.762
# ...

# %%
# %cd /home/thuannd/Yolov5/yolov5
# !python val.py --weights runs/train/exp4/weights/best.pt --data data/mydataset.yaml --img-size=640 --batch 16
# Out:
# /home/thuannd/Yolov5/yolov5
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# val: data=data/mydataset.yaml, weights=['runs/train/exp4/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.9.16 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24254MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7080247 parameters, 0 gradients, 16.0 GFLOPs
# val: Scanning /home/thuannd/Yolov5/yolov5/train/data/labels.cache... 10012 image
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 1.300s exceeded
# ...

# %%
# %cd /home/thuannd/Yolov5/yolov5
# !python detect.py --weights runs/train/exp2/weights/best.pt --source https://previews.123rf.com/images/ruslan_kokarev/ruslan_kokarev0711/ruslan_kokarev071100041/2071997-dried-and-rotten-pomegranates-on-the-white-paper.jpg
# Out:
# /home/thuannd/Yolov5/yolov5
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# detect: weights=['runs/train/exp2/weights/best.pt'], source=https://y5kbp0ifnvobj.vcdn.cloud/uploads/filecloud/2022/July/22/13135-635891658484507-1658484507.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# ...
# 100%|██████████████████████████████████████| 53.5k/53.5k [00:00<00:00, 1.32MB/s]
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.9.16 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24254MiB)
#
# Fusing layers...
# ...

# %%
# %cd /home/thuannd/Yolov5/yolov5
from IPython.display import Image, display
display(Image(filename="runs/detect/exp9/13135-635891658484507-1658484507.jpg"))
# Out:
# /home/thuannd/Yolov5/yolov5

# %%
# %cd /home/thuannd/Yolov5/yolov5
# !python detect.py --weights runs/train/exp2/weights/best.pt --source https://vinmec-prod.s3.amazonaws.com/images/20220128_063156_131130_an-oi-nhieu-co-tot-.max-1800x1800.jpg
# Out:
# /home/thuannd/Yolov5/yolov5
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# detect: weights=['runs/train/exp2/weights/best.pt'], source=https://vinmec-prod.s3.amazonaws.com/images/20220128_063156_131130_an-oi-nhieu-co-tot-.max-1800x1800.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# Found https://vinmec-prod.s3.amazonaws.com/images/20220128_063156_131130_an-oi-nhieu-co-tot-.max-1800x1800.jpg locally at 20220128_063156_131130_an-oi-nhieu-co-tot-.max-1800x1800.jpg
# ...

# %%
# %cd /home/thuannd/Yolov5/yolov5
from IPython.display import Image, display
display(Image(filename="runs/detect/exp10/20220128_063156_131130_an-oi-nhieu-co-tot-.max-1800x1800.jpg"))
# Out:
# /home/thuannd/Yolov5/yolov5

# %%
# %cd /home/thuannd/Yolov5/yolov5
from IPython.display import Image, display
display(Image(filename="runs/detect/exp7/2071997-dried-and-rotten-pomegranates-on-the-white-paper.jpg"))
# Out:
# /home/thuannd/Yolov5/yolov5
